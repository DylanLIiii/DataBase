# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np


input_data = pd.read_excel(r'/Users/dylan/DataBase/signal_process/top3-pc_ratio_rank-30.xlsx')
signal_result = pd.read_excel(r'/Users/dylan/DataBase/signal_process/benchmark_result-30_5.xlsx')

# %%
input_model = input_data['model_selected'].shift(-1).dropna()
input_model_df = pd.DataFrame()
for i in range(len(input_model)): 
    # 将字符串转换为字典,并转化为dataframe
    new_df = pd.DataFrame.from_dict(eval(input_model.iloc[i]),orient = 'index',columns = ['signal'])
    input_model_df = input_model_df.append(new_df)
input_model_df = input_model_df.reset_index().rename(columns = {'index' : 'model'})
type(eval(input_model.iloc[1]))
# Out:
# dict

# %%
input_model_df
# Out:
#                   model  signal
# 0    2日开盘价持续下跌-1121-xgb    0.33
# 1    2日开盘价持续下跌-1121-rfc    0.33
# 2    2日开盘价持续下跌-1121-dtc    0.33
# 3   2日开盘价持续下跌-1222-bagc    0.34
# 4    2日开盘价持续下跌-1120-dtc    0.33
# ..                  ...     ...
# 67  2日开盘价持续下跌-1131-bagc    0.33
# 68  2日开盘价持续下跌-1222-bagc    0.32
# 69  2日开盘价持续下跌-1122-knnc    0.35
# 70  2日开盘价持续下跌-1133-knnc    0.35
# 71  2日开盘价持续下跌-1131-bagc    0.31
#
# [72 rows x 2 columns]

# %%
# 频次统计
df = input_model_df.loc[:,'model'].value_counts().to_frame()
df.reset_index(level=0, inplace=True)
fig = plt.gcf()
fig.set_size_inches( 16, 10)

image = sns.barplot(data = df.groupby(by = 'model').agg('count'), x = [1,2,3,4],y = 'index' )
image.set_xlabel('Number of occurrences')
image.set_ylabel('times')
df.groupby(by = 'model').agg('count')
for x,y in zip([1,2,3,4],list(df.groupby(by = 'model').agg('count')['index'])):
    image.text(x-1,y+0.2,y) # 坐标轴的位置进行了重新排序

# %%
# 涉及模型
input_model_df.drop_duplicates('model').count()
# Out:
# model     38
# signal    38
# dtype: int64

# %%
# 涉及模型的数量
input_model_df.drop_duplicates('model').count()

input_model_df
# Out:
#                   model  signal
# 0    2日开盘价持续下跌-1121-xgb    0.33
# 1    2日开盘价持续下跌-1121-rfc    0.33
# 2    2日开盘价持续下跌-1121-dtc    0.33
# 3   2日开盘价持续下跌-1222-bagc    0.34
# 4    2日开盘价持续下跌-1120-dtc    0.33
# ..                  ...     ...
# 67  2日开盘价持续下跌-1131-bagc    0.33
# 68  2日开盘价持续下跌-1222-bagc    0.32
# 69  2日开盘价持续下跌-1122-knnc    0.35
# 70  2日开盘价持续下跌-1133-knnc    0.35
# 71  2日开盘价持续下跌-1131-bagc    0.31
#
# [72 rows x 2 columns]

# %%
# 每期替换
list1 = list(input_data['start_date'])
del list1[-1]
list2 = range(int(len(input_model_df)/3))
#input_data.insert(input_data.shape[1],'count',0)
for i,x in zip(list2, list1): 
    if i*3 == len(input_model_df) - 3:
        break
    i = 3*i
    filter = input_model_df.iloc[i:i+3].append(input_model_df.iloc[i+3:i+6])
    filter = filter.drop_duplicates('model')
    count = 3 - (6 - filter.count())
    input_data.loc[input_data['start_date'] == x,'count'] = int(count.iloc[0])
input_data['count'] = input_data['count'].shift(1)
print(input_data)
plt.figure(figsize=(15, 10))
image = sns.barplot(data = input_data.groupby(by = 'count').agg('count'),x = [1,2,3],y = 'start_date')

image.set_ylabel('times')

input_data.groupby(by = 'count').agg('count')

for x,y in zip([1,2,3],list(input_data.groupby(by = 'count').agg('count')['start_date'])):
    image.text(x-1,y+0.2,y) # 坐标轴的位置进行了重新排序
# Out:
#     start_date    end_date                                              model  \
# 0   2018-05-01  2018-06-12  {'2日开盘价持续下跌-1121-xgb': 0.33, '2日开盘价持续下跌-1121-r...
# 1   2018-06-13  2018-07-25  {'2日开盘价持续下跌-1222-bagc': 0.34, '2日开盘价持续下跌-1120-...
# 2   2018-07-26  2018-09-05  {'2日开盘价持续下跌-1220-bagc': 0.34, '2日开盘价持续下跌-1131-...
# 3   2018-09-06  2018-10-25  {'2日开盘价持续下跌-1131-rfc': 0.32, '2日开盘价持续下跌-1131-k...
# 4   2018-10-26  2018-12-06  {'2日开盘价持续下跌-1122-xgb': 0.33, '2日开盘价持续下跌-1122-r...
# 5   2018-12-07  2019-01-21  {'2日开盘价持续下跌-1133-bagc': 0.33, '2日开盘价持续下跌-1220-...
# 6   2019-01-22  2019-03-11  {'2日开盘价持续下跌-1121-bagc': 0.33, '2日开盘价持续下跌-1120-...
# 7   2019-03-12  2019-04-23  {'2日开盘价持续下跌-1120-rfc': 0.33, '2日开盘价持续下跌-1121-k...
# 8   2019-04-24  2019-06-10  {'2日开盘价持续下跌-1130-bagc': 0.34, '2日开盘价持续下跌-1120-...
# 9   2019-06-11  2019-07-22  {'2日开盘价持续下跌-1120-xgb': 0.33, '2日开盘价持续下跌-1222-x...
# 10  2019-07-23  2019-09-02  {'2日开盘价持续下跌-1133-rfc': 0.35, '2日开盘价持续下跌-1121-r...
# 11  2019-09-03  2019-10-22  {'2日开盘价持续下跌-1122-rfc': 0.33, '2日开盘价持续下跌-1122-d...
# 12  2019-10-23  2019-12-03  {'2日开盘价持续下跌-1120-xgb': 0.32, '2日开盘价持续下跌-1131-d...
# 13  2019-12-04  2020-01-15  {'2日开盘价持续下跌-1230-bagc': 0.34, '2日开盘价持续下跌-1121-...
# 14  2020-01-16  2020-03-05  {'2日开盘价持续下跌-1222-knnc': 0.34, '2日开盘价持续下跌-1133-...
# 15  2020-03-06  2020-04-17  {'2日开盘价持续下跌-1221-bagc': 0.33, '2日开盘价持续下跌-1133-...
# 16  2020-04-20  2020-06-03  {'2日开盘价持续下跌-1222-rfc': 0.34, '2日开盘价持续下跌-1132-l...
# 17  2020-06-04  2020-07-17  {'2日开盘价持续下跌-1120-knnc': 0.33, '2日开盘价持续下跌-1121-...
# 18  2020-07-20  2020-08-28  {'2日开盘价持续下跌-1131-rfc': 0.34, '2日开盘价持续下跌-1131-b...
# 19  2020-08-31  2020-10-19  {'2日开盘价持续下跌-1120-xgb': 0.33, '2日开盘价持续下跌-1121-r...
# 20  2020-10-20  2020-11-30  {'2日开盘价持续下跌-1220-rfc': 0.34, '2日开盘价持续下跌-1133-b...
# 21  2020-12-01  2021-01-12  {'2日开盘价持续下跌-1130-dtc': 0.32, '2日开盘价持续下跌-1130-r...
# 22  2021-01-13  2021-03-02  {'2日开盘价持续下跌-1220-bagc': 0.34, '2日开盘价持续下跌-1131-...
# 23  2021-03-03  2021-04-14  {'2日开盘价持续下跌-1122-knnc': 0.35, '2日开盘价持续下跌-1133-...
# 24  2021-04-15  2021-05-31  {'2日开盘价持续下跌-1131-lr': 0.33, '2日开盘价持续下跌-1131-rf...
#
#     annual_return_op  sharpe_ratio_op  win_rate_op  pc_ratio_op  \
# 0               1.13             0.72         0.00         0.92
# 1               1.04             0.50         0.67         1.54
# 2              -2.31            -1.31         0.29         0.98
# 3               1.63             0.70         0.31         1.39
# 4              -1.82            -1.28         0.04         0.88
# 5              -0.33            -0.43         0.12         0.88
# 6               8.00             3.10         0.12         1.59
# 7               7.41             4.01         0.36         1.93
# 8              -4.53            -3.23         0.62         1.11
# 9               5.05             2.85         0.50         2.08
# 10              0.19             0.06         0.48         0.96
# 11              0.22             0.10         0.30         0.98
# 12             -3.67            -3.47         0.53         1.08
# 13              2.44             5.47         0.45         1.38
# 14              7.24             3.98         0.21         1.29
# 15             -0.88            -0.33         0.50         1.00
# 16              2.44             1.65         0.54         1.25
# 17              9.79             3.44         0.56         1.77
# 18              4.55             2.60         0.67         1.08
# 19              2.08             1.48         0.53         1.06
# 20              1.94             1.67         0.38         0.84
# 21              3.28             5.45         0.40         2.73
# 22             -0.53            -0.32         0.62         1.35
# 23             -7.29            -5.12         0.50         1.00
# 24              4.60             2.43         0.57         1.87
#
#     annual_return_sp  sharpe_ratio_sp  win_rate_sp  pc_ratio_sp   sp_rank  \
# 0               4.47             5.34         0.48        21.08  0.926230
# 1               5.53             2.78         0.75         1.89  1.000000
# 2               2.17             2.27         0.59         4.84  1.000000
# 3               4.58             2.14         0.38         1.97  0.938596
# 4               1.69             1.75         0.52         2.16  0.967213
# 5               0.63             0.74         0.56         1.14  0.961538
# 6              12.93             5.89         0.42         3.00  0.964912
# 7               5.34             3.87         0.59         5.04  0.968085
# 8              -0.89            -0.91         0.57         2.00  1.000000
# 9               5.13             2.90         0.00         2.11  0.935897
# 10              1.34             1.07         0.43         1.50  1.000000
# 11              0.49             1.58         0.47        31.76  0.952381
# 12             -1.61            -1.85         0.53         1.43  0.836207
# 13              2.21             6.79         0.45        34.06  0.983607
# 14              2.30             2.32         0.34         5.92  1.000000
# 15             -1.87            -0.80         0.50         1.36  0.968750
# 16              1.54             1.03         0.46         1.99  1.000000
# 17              4.72             3.50         0.50         3.30  0.968085
# 18              8.57             5.99         0.50         4.38  0.983871
# 19              2.35             2.21         0.37         2.48  0.976190
# 20              3.27             4.16         0.43         3.47  1.000000
# 21              2.98             6.20         0.45        10.37  0.947368
# 22              5.60             3.63         0.69         2.05  1.000000
# 23             -5.47            -4.16         0.60         1.25  0.973684
# 24           -100.00            -2.93         0.43         0.19  0.969388
#
#                                        model_selected  count
# 0                                                 NaN    NaN
# 1   {'2日开盘价持续下跌-1121-xgb': 0.33, '2日开盘价持续下跌-1121-r...    3.0
# 2   {'2日开盘价持续下跌-1222-bagc': 0.34, '2日开盘价持续下跌-1120-...    3.0
# 3   {'2日开盘价持续下跌-1220-bagc': 0.34, '2日开盘价持续下跌-1131-...    2.0
# 4   {'2日开盘价持续下跌-1131-rfc': 0.32, '2日开盘价持续下跌-1131-k...    3.0
# 5   {'2日开盘价持续下跌-1122-xgb': 0.33, '2日开盘价持续下跌-1122-r...    3.0
# 6   {'2日开盘价持续下跌-1133-bagc': 0.33, '2日开盘价持续下跌-1220-...    3.0
# 7   {'2日开盘价持续下跌-1121-bagc': 0.33, '2日开盘价持续下跌-1120-...    1.0
# 8   {'2日开盘价持续下跌-1120-rfc': 0.33, '2日开盘价持续下跌-1121-k...    3.0
# 9   {'2日开盘价持续下跌-1130-bagc': 0.34, '2日开盘价持续下跌-1120-...    3.0
# 10  {'2日开盘价持续下跌-1120-xgb': 0.33, '2日开盘价持续下跌-1222-x...    3.0
# 11  {'2日开盘价持续下跌-1133-rfc': 0.35, '2日开盘价持续下跌-1121-r...    3.0
# 12  {'2日开盘价持续下跌-1122-rfc': 0.33, '2日开盘价持续下跌-1122-d...    3.0
# 13  {'2日开盘价持续下跌-1120-xgb': 0.32, '2日开盘价持续下跌-1131-d...    3.0
# 14  {'2日开盘价持续下跌-1230-bagc': 0.34, '2日开盘价持续下跌-1121-...    3.0
# 15  {'2日开盘价持续下跌-1222-knnc': 0.34, '2日开盘价持续下跌-1133-...    1.0
# 16  {'2日开盘价持续下跌-1221-bagc': 0.33, '2日开盘价持续下跌-1133-...    3.0
# 17  {'2日开盘价持续下跌-1222-rfc': 0.34, '2日开盘价持续下跌-1132-l...    3.0
# 18  {'2日开盘价持续下跌-1120-knnc': 0.33, '2日开盘价持续下跌-1121-...    3.0
# 19  {'2日开盘价持续下跌-1131-rfc': 0.34, '2日开盘价持续下跌-1131-b...    3.0
# 20  {'2日开盘价持续下跌-1120-xgb': 0.33, '2日开盘价持续下跌-1121-r...    3.0
# 21  {'2日开盘价持续下跌-1220-rfc': 0.34, '2日开盘价持续下跌-1133-b...    3.0
# 22  {'2日开盘价持续下跌-1130-dtc': 0.32, '2日开盘价持续下跌-1130-r...    3.0
# 23  {'2日开盘价持续下跌-1220-bagc': 0.34, '2日开盘价持续下跌-1131-...    2.0
# 24  {'2日开盘价持续下跌-1122-knnc': 0.35, '2日开盘价持续下跌-1133-...    2.0

# %%
# 在验证期超过benchmark的比例
list1 = list(range(int(len(input_model_df)/3)))
list2 = list(input_data['end_date'])
# del list2[0]
model_df = pd.DataFrame()
for i,x in zip(list1,list2) :
        i = 3*i
        filter = input_model_df.iloc[i:i+3]    
        for model in filter['model']: 
                # modelmark可能为空
                model_mark = signal_result[(signal_result['end_date'] == x) & (signal_result['model'] == model)]
                #print(model_mark)
                # benchmark可能为空
                benchmark = signal_result[(signal_result['end_date'] == x) & (signal_result['model'] == 'benchmark')]
                #print(benchmark)
                if model_mark.empty or benchmark.empty :
                        break
                if model_mark['sharpe_ratio_sp'].iloc[0] >= benchmark['sharpe_ratio_sp'].iloc[0] :
                        model_mark['larger_now'] = 1
                else: 
                        model_mark['larger_now'] = 0
                model_df = model_df.append(model_mark)
        model_df = model_df.append(benchmark)
# 观测数据
model_df.count()
model_df[model_df['larger_now'] == 1].count()
#model_df[model_df['larger_now'] == 0].count()
model_df.head(50)

def get_large_ratio(x): 
        ratio = x[x == 1].count() / 3
        return ratio
# 超过比例
model_df['ratio_now'] = model_df.groupby('start_date')['larger_now'].transform(get_large_ratio)
model_df.to_excel(r'/Users/dylan/DataBase/Top3-model-ratio-now.xlsx')
# Out:
# <ipython-input-9-ec54847b8742>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_mark['larger_now'] = 1
# <ipython-input-9-ec54847b8742>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_mark['larger_now'] = 0

# %%
# 在验证期超过benchmark的比例
list1 = list(range(int(len(input_model_df)/7)))
list2 = list(input_data['end_date'])
del list2[0]
print(list2)
model_df = pd.DataFrame()
for i,x in zip(list1,list2) :
        i = 7*i
        filter = input_model_df.iloc[i:i+7]    
        for model in filter['model']: 
                # modelmark可能为空
                model_mark = signal_result[(signal_result['end_date'] == x) & (signal_result['model'] == model)]
                #print(model_mark)
                # benchmark可能为空
                benchmark = signal_result[(signal_result['end_date'] == x) & (signal_result['model'] == 'benchmark')]
                #print(benchmark)
                if model_mark.empty or benchmark.empty :
                        break
                if model_mark['sharpe_ratio_sp'].iloc[0] >= benchmark['sharpe_ratio_sp'].iloc[0] :
                        model_mark['larger_next'] = 1
                else: 
                        model_mark['larger_next'] = 0
                model_df = model_df.append(model_mark)
        model_df = model_df.append(benchmark)
model_df.count()
def get_large_ratio(x): 
        ratio = x[x == 1].count() / 7 
        return ratio
model_df['ratio_next'] = model_df.groupby('start_date')['larger_next'].transform(get_large_ratio)
model_df.to_excel(r'/Users/dylan/DataBase/Top3-model-ratio-next.xlsx')
# Out:
# ['2018-07-25', '2018-09-05', '2018-10-25', '2018-12-06', '2019-01-21', '2019-03-11', '2019-04-23', '2019-06-10', '2019-07-22', '2019-09-02', '2019-10-22', '2019-12-03', '2020-01-15', '2020-03-05', '2020-04-17', '2020-06-03', '2020-07-17', '2020-08-28', '2020-10-19', '2020-11-30', '2021-01-12', '2021-03-02', '2021-04-14', '2021-05-31']
# <ipython-input-10-cddd501f17f5>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_mark['larger_next'] = 1
# <ipython-input-10-cddd501f17f5>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_mark['larger_next'] = 0
